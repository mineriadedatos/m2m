# %% [markdown]
# ### Fracciones, potencias, subíndices
# En línea: \( E = mc^2 \), \( x_i^2 \), \( \frac{a}{b+c} \)
#
# En línea: $E = mc^2$, $x_i^2$, $\frac{a}{b+c}$
#
#
#
# Bloque:
# $$
# \hat{y} = \beta_0 + \sum_{j=1}^p \beta_j x_j
# $$

# %% [markdown]
# ### Matriz y vector
# $$
# \mathbf{X} =
# \begin{bmatrix}
# x_{11} & x_{12} \\
# x_{21} & x_{22}
# \end{bmatrix},
# \quad
# \vec{w} =
# \begin{bmatrix}
# w_1 \\ w_2
# \end{bmatrix}
# $$

# %% [markdown]
# $$
# J(\theta)=\frac{1}{m}\sum_{i=1}^{m}\bigl(h_\theta(x^{(i)})-y^{(i)}\bigr)^2,
# \qquad
# \theta^\*=\arg\min_{\theta} J(\theta)
# $$

# %% [markdown]
# ### Sumatoria / argmin
# $$
# f(x)=
# \begin{cases}
# x^2 & \text{si } x\ge 0,\\
# -x  & \text{si } x<0.
# \end{cases}
# $$

# %% [markdown]
# ### Alineación de pasos (amsmath)
#
# $$
# \begin{aligned}
# \nabla_w J(w)
# &= \frac{1}{m}\sum_{i=1}^m 2\,(w^\top x^{(i)}-y^{(i)})\,x^{(i)} \\
# &= \frac{2}{m}\,X^\top(Xw-y)
# \end{aligned}
# $$

# %% [markdown]
# ### Números de ecuación (opcional)
# $$
# \label{eq:ridge}
# \min_w \ \|y-Xw\|_2^2 + \lambda\|w\|_2^2 \tag{1}
# $$
