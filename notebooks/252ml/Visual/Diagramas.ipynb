# %% [markdown]
# ## MermaId

# %% [markdown]
# ### 1) `flowchartDiagram`
#
# ```mermaid
# flowchart TD
#   A[Inicio] --> B{¿Dato limpio?}
#   B -- Sí --> C[Entrenar modelo]
#   B -- No --> D[Preprocesar]
#   C --> E[Evaluar]
#   D --> C

# %% [markdown]
# ### 2) `sequenceDiagram`
#
# ```mermaid
# sequenceDiagram
#   autonumber
#   participant U as Usuario
#   participant NB as Notebook
#   participant ML as Modelo
#
#   U->>NB: Carga datos
#   NB-->>U: Muestra preview
#   U->>NB: Ejecuta "Entrenar"
#   NB->>ML: fit(X_train, y_train)
#   ML-->>NB: métricas (acc, f1)
#   NB-->>U: Renderiza reporte

# %% [markdown]
# ### 3) `erDiagram` (Entidad–Relación)
#
# ```mermaid
# erDiagram
#   CLIENTE ||--o{ PEDIDO : realiza
#   PEDIDO }o--o{ PRODUCTO : contiene
#   PRODUCTO }o--|| CATEGORIA : pertenece
#   CLIENTE {
#     int id
#     string nombre
#     string email
#   }
#   PEDIDO {
#     int id
#     date fecha
#     float total
#   }
#   PRODUCTO {
#     int id
#     string nombre
#     float precio
#   }
#   CATEGORIA {
#     int id
#     string nombre
#   }

# %% [markdown]
# ### 4) `classDiagram` para pipelines
#
# ```mermaid
# classDiagram
#   class Pipeline {
#     +fit(X, y)
#     +predict(X)
#     -steps
#   }
#   class Preprocess {
#     +transform(X)
#   }
#   class Model {
#     +fit(X, y)
#     +predict(X)
#   }
#   Pipeline o-- Preprocess
#   Pipeline o-- Model
